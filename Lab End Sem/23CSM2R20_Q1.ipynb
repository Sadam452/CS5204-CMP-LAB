# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('housing.csv')

# %%
display(data)
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  MedHouseVal
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
data.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
y = data['MedHouseVal'], 
X = data.drop('MedHouseVal', axis=1)

# %%
columns = ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
       'Latitude', 'Longitude', 'MedHouseVal']

# %%
#center the data by subtracting the mean
#1. Center the data by subtracting the mean from each feature column.
for i in range(0, len(columns)):
    data[columns[i]] -= np.mean(data[columns[i]])

# %%
data.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04
# mean   9.914550e-17 -1.057552e-15  2.203233e-16 -4.750722e-17 -5.781284e-14
# std    1.899822e+00  1.258556e+01  2.474173e+00  4.739109e-01  1.132462e+03
# min   -3.370771e+00 -2.763949e+01 -4.582846e+00 -7.633418e-01 -1.422477e+03
# 25%   -1.307271e+00 -1.063949e+01 -9.882835e-01 -9.059610e-02 -6.384767e+02
# 50%   -3.358710e-01  3.605136e-01 -1.998710e-01 -4.789466e-02 -2.594767e+02
# 75%    8.725790e-01  8.360514e+00  6.233812e-01  2.850917e-03  2.995233e+02
# max    1.112943e+01  2.336051e+01  1.364801e+02  3.296999e+01  3.425652e+04
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04
# mean   6.609700e-17 -2.247298e-15 -1.718522e-14  2.313395e-16
# std    1.038605e+01  2.135952e+00  2.003532e+00  1.153956e+00
# ...

# %%
#Calculate the covariance matrix of the centered data.
data_t = np.transpose(data)
cov = np.cov(data_t)

# %%
print(cov.shape)
# Out:
# (9, 9)

# %%
cov
# Out:
# array([[ 3.60932256e+00, -2.84614028e+00,  1.53656801e+00,
#         -5.58575949e-02,  1.04009792e+01,  3.70288896e-01,
#         -3.23859753e-01, -5.77647021e-02,  1.50847483e+00],
#        [-2.84614028e+00,  1.58396260e+02, -4.77288245e+00,
#         -4.63718412e-01, -4.22227058e+03,  1.72429796e+00,
#          3.00345508e-01, -2.72824366e+00,  1.53398801e+00],
#        [ 1.53656801e+00, -4.77288245e+00,  6.12153272e+00,
#          9.93867801e-01, -2.02333712e+02, -1.24688866e-01,
#          5.62235473e-01, -1.36518371e-01,  4.33825637e-01],
#        [-5.58575949e-02, -4.63718412e-01,  9.93867801e-01,
#          2.24591500e-01, -3.55272253e+01, -3.04242537e-02,
#          7.05752856e-02,  1.26704371e-02, -2.55392194e-02],
#        [ 1.04009792e+01, -4.22227058e+03, -2.02333712e+02,
#         -3.55272253e+01,  1.28247046e+06,  8.21712002e+02,
#         -2.63137814e+02,  2.26377839e+02, -3.22124873e+01],
#        [ 3.70288896e-01,  1.72429796e+00, -1.24688866e-01,
# ...

# %%
#. Find the eigenvalues and eigenvectors of the covariance matrix.
eigenvalues, eigenvectors = np.linalg.eig(cov)

# %%
print("Eigenvalues:",eigenvalues)
print("Eigenvectors:",eigenvectors)
# Out:
# Eigenvalues: [1.28248501e+06 1.45324457e+02 1.06833933e+02 8.26511883e+00
#  6.81872331e+00 3.54012460e+00 5.69652184e-01 2.96508421e-02
#  1.91330396e-01]
# Eigenvectors: [[-8.11731559e-06 -1.96987961e-02 -6.66374709e-03  2.92853723e-02
#    4.68029430e-01 -7.36674581e-01  4.68599681e-01  1.17705480e-01
#   -5.94027965e-02]
#  [ 3.29264424e-03  9.92188045e-01  1.15156340e-01  3.34080253e-03
#    4.18261697e-02  1.11015570e-02  1.94551086e-02  1.56362635e-04
#    5.35720791e-03]
#  [ 1.57754716e-04 -3.89771596e-02 -6.37020760e-03  2.27191076e-01
#    8.23436126e-01  4.78918415e-01 -4.35912172e-02 -1.88713067e-01
#   -4.36081852e-02]
#  [ 2.77006678e-05 -4.23984008e-03 -6.14289698e-04  3.15805779e-02
#    1.13826693e-01  1.57844894e-01 -1.17086338e-01  9.72514741e-01
#   -4.02325064e-02]
#  [-9.99994324e-01  3.18879289e-03  1.01441733e-03  3.12082223e-04
#    2.17405589e-04  8.61258703e-05  3.41965983e-05 -1.10538927e-06
#    3.16717668e-05]
# ...

# %%
#4. Select the top k eigenvectors corresponding to the largest eigenvalues (where
#k¡ d is the desired reduced dimension).
k=6
vec = np.transpose(eigenvectors[:k])
data2 = np.dot(data, vec)

# %%
data2 = pd.DataFrame(data2)
data2
# Out:
#                 0          1           2           3         4         5
# 0     -515.741785 -33.645977 -909.099973 -128.691226 -4.653323  2.675441
# 1      458.064876  33.370335  803.422786  108.017655 -4.242154 -4.178106
# 2     -434.665854 -15.310570 -766.082862 -108.858120 -3.511297  2.209053
# 3     -405.438977 -13.010594 -715.129624 -101.844927 -1.886058  4.506404
# 4     -401.896177 -12.674231 -709.542897 -101.106431 -0.087204  4.027940
# ...           ...        ...         ...         ...       ...       ...
# 20635 -269.528344 -27.879758 -477.902226  -68.014769  2.172224  1.419703
# 20636 -498.681633 -55.144763 -879.962955 -123.669940  1.048287  0.792464
# 20637 -193.425511 -29.025413 -344.289775  -49.704813  2.042375 -0.074948
# 20638 -317.798482 -39.146656 -563.426510  -80.111534  1.820658  0.593105
# 20639  -15.797102 -14.113677  -31.188508   -6.410380  1.433290 -1.205114
#
# [20640 rows x 6 columns]

# %%
for i in range(0,5):
    plt.scatter(data2[i], y)
    plt.title(i)
    plt.show()

# %%
for i in range(0,len(columns)):
    plt.title(columns[i])
    plt.scatter(data[columns[i]],y)
    plt.show()
